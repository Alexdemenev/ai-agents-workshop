# %%
import pandas as pd
import numpy as np
import requests
from dotenv import load_dotenv
import os
from openai import OpenAI
import json

# %%
from IPython.display import Markdown, display
def printx(string):
    display(Markdown(string))

# %%
# configs
load_dotenv()
api_key = os.getenv('YANDEX_API_KEY')
folder_id = os.getenv('FOLDER_ID')

# %% [markdown]
# ### Определение класса агента
#
# Данный класс способен принимать на вход различные инструменты в виде python функций, а также создавать и пополнять векторную базу данных для настройки RAG.

# %%
import os


# model = f"gpt://{folder_id}/yandexgpt/latest"
model = f"gpt://{folder_id}/gemma-3-27b-it/latest"
# model = f"gpt://{folder_id}/gpt-oss-120b/latest"
# model = f"gpt://{folder_id}/qwen2-vl-7b-instruct"

client = OpenAI(
    base_url="https://rest-assistant.api.cloud.yandex.net/v1",
    api_key=api_key,
    project=folder_id
)

# %%
prompt = "Привет"

res = client.responses.create(
    model = model,
    input = [
        {
            "role": "user",
            "content": [
                {"type": "input_text", "text": prompt},
            ],
        }
    ],
)

print(res.output_text)
# Out:
# Привет! Чем могу помочь? Что тебя интересует?

# %%
import io

class Agent():

    def __init__(self,
            name,
            instruction, 
            tools = [], search_content = [], 
            model = model,
            response_format = None
            ):
        self.user_sessions = {}
        self.name = name
        self.instruction = instruction
        self.model = model
        self.tool_map = { x.__name__ : x for x in tools if issubclass(x, BaseModel) }
        self.tools = [
            self._create_tool_annot(x) for x in tools
        ]
        self.response_format = response_format
        self.vector_store = None
        if search_content:
            i=0
            self.vector_store = client.vector_stores.create(name=f'rag_store_{self.name}')
            for c in search_content:
                f = client.files.create(
                        purpose="assistants",
                        file = (f'rag_{self.name}_{i}.txt',io.BytesIO(c.encode("utf-8")),'text/markdown'))
                client.vector_stores.files.create(file_id=f.id, vector_store_id=self.vector_store.id)
                print(f" + Uploading rag_{self.name}_{i}.txt as id={f.id} to store={self.vector_store.id}")
                i+=1
            self.tools.append({
                "type" : "file_search",
                "vector_store_ids" : [self.vector_store.id],
                "max_num_results" : 5,
            })
            
    def _create_tool_annot(self, x):
        if issubclass(x, BaseModel):
            return {
                "type": "function",
                "name": x.__name__,
                "description": x.__doc__,
                "parameters": x.model_json_schema(),
            }
        else:
            return x

    def __call__(self, message, session_id='default',return_raw=False):
        s = self.user_sessions.get(session_id,{ 'previous_response_id' : None, 'history' : [] })
        s['history'].append({ 'role': 'user', 'content': message })
        txt = None
        if self.response_format:
            txt = {
                "format" : {
                    "type" : "json_schema",
                    "name" : "struct_out",
                    "schema" : self.response_format.model_json_schema()
                }
            }
        res = client.responses.create(
            model = self.model,
            store = True,
            tools = self.tools,
            instructions = self.instruction,
            previous_response_id = s['previous_response_id'],
            input = message,
            text = txt
        )
        # Обрабатываем вызов локальных инструментов
        tool_calls = [item for item in res.output if item.type == "function_call"]
        if tool_calls:
            s['history'].append({ 'role' : 'func_call', 'content' : res.output_text })
            out = []
            for call in tool_calls:
                print(f" + Обрабатываем: {call.name} ({call.arguments})")
                try:
                    fn = self.tool_map[call.name]
                    obj = fn.model_validate(json.loads(call.arguments))
                    result = obj.process(session_id)
                except Exception as e:
                    result = f"Ошибка: {e}"
                #print(f" + Результат: {result}")
                out.append({
                    "type": "function_call_output",
                    "call_id": call.call_id,
                    "output": result
                })
                res = client.responses.create(
                    model=self.model,
                    input=out,
                    tools=self.tools,
                    previous_response_id=res.id,
                    store=True
                )
        # MCP Approval Requests
        mcp_approve = [ item for item in res.output if item.type == "mcp_approval_request"]
        if mcp_approve:
            res = client.responses.create(
                model=self.model,
                previous_response_id=res.id,
                tools = self.tools,
                input=[{
                    "type": "mcp_approval_response",
                    "approve": True,
                    "approval_request_id": m.id
                }
                for m in mcp_approve
                ])
        s['previous_response_id'] = res.id
        s['history'].append({ 'role' : 'assistant', 'content' : res.output_text })
        self.user_sessions[session_id] = s
        if return_raw:
            return res
        if self.response_format:
            return self.response_format.model_validate_json(res.output_text)
        else:
            return res.output_text

    def history(self, session_id='default'):
        return self.user_sessions[session_id]['history']

# %% [markdown]
# ### Агент-консультант СЛФ
#
# В примере будет использоваться каталог СЛФ для создания агента, который способен ориентироваться в каталоге. Вместо файла каталога можно использоваться другие документы: нормативные акты, учебники, датасеты

# %%
# сохраняем файл, который будем использовать для RAG, в формате markdown
catalog = pd.read_parquet('./nomen.parquet')
catalog[['name', 'article']].to_markdown('nomen.md')

# %%
# здесь указывается путь к файлу с каталогом в формате markdown
with open("./nomen.md", encoding="utf-8") as f:
    food_wine = f.readlines()
header = food_wine[:2]
chunk_size = 1000 * 3  # approx 1000 tokens * 3 char/token
docs = []
s = header.copy()
for x in food_wine[2:]:
    s.append(x)
    if len("".join(s)) > chunk_size:
        docs.append("".join(s))
        s = header.copy()

# %%
prompt = f"""
Ты - консультант на складе поставщика продуктов для сегмента HoReCa, который должен советовать клиентам продукты и отвечать 
на вопросы по ассортименту продуктов, используя имеющуюся у тебя информацию. Если в каталоге нет указанного продукта
 - напиши, что продукт отсутствует в каталоге. Не придумывай ничего!
"""

consultant = Agent(
    'consultant',
    search_content=docs,
    instruction=prompt)
# Out:
#  + Uploading rag_consultant_0.txt as id=fvtkfauihf7gq40p314b to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_1.txt as id=fvt1e738167qgv6or80k to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_2.txt as id=fvtovpn31bc6urhq9va9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_3.txt as id=fvtp6fh4dc6f5omvv4tm to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_4.txt as id=fvti55e4hifoeltblmrb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_5.txt as id=fvt1h4kvod1ra74df0dm to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_6.txt as id=fvtqssebhrvvj7ek11d3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_7.txt as id=fvtabj1lrhtgfn68h9nk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_8.txt as id=fvtvo2kgf2v7msjsgb53 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_9.txt as id=fvtahj8j07s4uhp72h96 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_10.txt as id=fvtf9lrh1p26m6uvjidq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_11.txt as id=fvtjlsbqi18ugf2lvtfr to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_12.txt as id=fvt0l94c71tndvqh4con to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_13.txt as id=fvti95odp3cbkoicbctj to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_14.txt as id=fvtept6gie0hokio16gn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_15.txt as id=fvtcti36gmqs04j9nglb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_16.txt as id=fvtj2mqccvptn6nsmih3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_17.txt as id=fvtdivrsq6e80ac0u6na to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_18.txt as id=fvtlqjci0v8d86fdgbsd to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_19.txt as id=fvtd5k06mf04bvqd3mtc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_20.txt as id=fvt6fmcrqe5rp6u2amjj to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_21.txt as id=fvtmdpj5iv2fbjulbfti to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_22.txt as id=fvtkhk9o3c2asm9thntt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_23.txt as id=fvth235ll3agjg1tujqo to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_24.txt as id=fvtf2atlrtehv2961lfs to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_25.txt as id=fvtkqk8erbe08ia3p07s to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_26.txt as id=fvtr3t6ri7gppl4aup8f to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_27.txt as id=fvtddv138uca2u45tmid to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_28.txt as id=fvtssv80oir81iklvha0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_29.txt as id=fvtv8bq5bgg16n4hi08u to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_30.txt as id=fvtjfneqov6a84e0lvl2 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_31.txt as id=fvtvhi877uf78fddq32h to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_32.txt as id=fvt0ion2938go8abb0r9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_33.txt as id=fvtdgljng71q0b8d4veo to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_34.txt as id=fvt51b1bkdmhqt7r57g9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_35.txt as id=fvth5a0ouhoh2jhgpjpo to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_36.txt as id=fvt9i9ipurt2a8i5q2jv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_37.txt as id=fvt8echhhcht675bqufo to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_38.txt as id=fvtvkjqtae2akmn866jc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_39.txt as id=fvt5qgc8q4u2usn2iuqh to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_40.txt as id=fvt4e6372s5thhsof42e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_41.txt as id=fvt18tp3382r4o85723f to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_42.txt as id=fvtqjt2edf5o7ciu54ua to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_43.txt as id=fvti8b3n6d8o5cphktsg to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_44.txt as id=fvt1nrkl7tpfa81pkjta to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_45.txt as id=fvttbv2merfgl957ocpe to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_46.txt as id=fvtsvq1p5dagsc9l1rip to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_47.txt as id=fvthq301q53f0mer3s6m to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_48.txt as id=fvte1o2bst64j9sabgem to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_49.txt as id=fvtiunrch8h9ggvveg39 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_50.txt as id=fvt09q6t3tescgb7skji to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_51.txt as id=fvt7oc8rnev5otflksvd to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_52.txt as id=fvt8e7p8a4fj2og4l9i7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_53.txt as id=fvtuv1srtvnc7994ffci to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_54.txt as id=fvtlpa8g90oia8kmn9tl to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_55.txt as id=fvtqccncj0gra3k0ssb0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_56.txt as id=fvt1jtss63hu3j5vj20e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_57.txt as id=fvtsu89sueof7c5ddbuj to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_58.txt as id=fvt3v7c1fd0g3adk14bf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_59.txt as id=fvtb61afiugq6pt38n0l to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_60.txt as id=fvt5qqvvlu2cb2okfb3d to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_61.txt as id=fvtbogrljt810he1d282 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_62.txt as id=fvt6icjg08r30geqpnhm to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_63.txt as id=fvtm9uf28u5ecbgkhogf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_64.txt as id=fvt1ko5i46cdr28akvkf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_65.txt as id=fvtj2kcv6oc1gnm2oal8 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_66.txt as id=fvt8dugbnhcr9ip1cteo to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_67.txt as id=fvtq26kbld44a7025tnv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_68.txt as id=fvtk32ngmt84nb0llomf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_69.txt as id=fvtk9scldfk7mfpk9b9r to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_70.txt as id=fvtc3n0uhnu26m06qof6 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_71.txt as id=fvtmebrfbppfg80ah6sr to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_72.txt as id=fvt6i7bba73qit9fv9a4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_73.txt as id=fvti50egkd9t22etlsc8 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_74.txt as id=fvtkd0im6t0vhov1dljt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_75.txt as id=fvtlo768mscaj38b9gsc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_76.txt as id=fvt8shli1g3tum3phg76 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_77.txt as id=fvt1f2qhs6pupnnjstis to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_78.txt as id=fvtrbrp9m32ku2eek8de to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_79.txt as id=fvttup0htb616m9664i5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_80.txt as id=fvtlqsjbil5sr9kj7kpc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_81.txt as id=fvthkvm3dlomka4a5hsu to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_82.txt as id=fvtde2cq19lilmshrhs1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_83.txt as id=fvtd6jlfc27n8nc41c8l to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_84.txt as id=fvtksb1vqdc94anmhpkm to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_85.txt as id=fvtjmmqlus7vt3081p9o to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_86.txt as id=fvtbc1ntmjrvcnr2790r to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_87.txt as id=fvt634unj2jj83qnbddd to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_88.txt as id=fvt1jb9hkqp74j2hoioi to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_89.txt as id=fvtpcl83rosoemgbic9i to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_90.txt as id=fvtmnr6tn67e9j9c5tpv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_91.txt as id=fvt8vjkb8g7rnbftu0p5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_92.txt as id=fvt3q5o7vmc6vq5b85bs to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_93.txt as id=fvt2sfd2cs3bcr1e1mvq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_94.txt as id=fvta5ckkqk4m14suqlbe to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_95.txt as id=fvte49lm40121mc3so8c to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_96.txt as id=fvtl9knv6q2deupbqobe to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_97.txt as id=fvtlgicej893m74av826 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_98.txt as id=fvt8l1anb0e3anahumpi to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_99.txt as id=fvto6ju0qci5h4pvh805 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_100.txt as id=fvt6m6ma1m8dfefj3tg3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_101.txt as id=fvte2alsv5l6onk9nj3m to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_102.txt as id=fvtvlato35muvqmpr6gt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_103.txt as id=fvthh94b961lf9hjd2qo to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_104.txt as id=fvt716som4qq7es9ocio to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_105.txt as id=fvtebrlrubb7422q32td to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_106.txt as id=fvto12oq47mt15h5fqk5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_107.txt as id=fvtlmngcjad1thksgurg to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_108.txt as id=fvt30qadnt45miuh64p9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_109.txt as id=fvtvfju4r64behmlqbei to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_110.txt as id=fvthbcjuv4gde2p8nqp3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_111.txt as id=fvtvfqkmu7nal3tk19lk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_112.txt as id=fvtnk1ehodo5h44b26d9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_113.txt as id=fvt44p21s3hbbpcqfcbq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_114.txt as id=fvtja605glm7ovgt8d1g to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_115.txt as id=fvtjl51956hlq554avnt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_116.txt as id=fvt0ujosj73thsq6vktc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_117.txt as id=fvtb67c13q0ei2fd62ou to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_118.txt as id=fvtd1nvgvfav4t4t7t4a to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_119.txt as id=fvtfe7ta36k1lcfaf276 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_120.txt as id=fvto7cnatk2370ol8l51 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_121.txt as id=fvtq3l7rm3u0lq112c9p to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_122.txt as id=fvtu66dbgeu5u943f9ds to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_123.txt as id=fvtbd6ne53it12l5bc6k to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_124.txt as id=fvtjatqitfk885cebjd7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_125.txt as id=fvtd9dejtksm4gfeu24j to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_126.txt as id=fvt19s30nmmnamahrfqn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_127.txt as id=fvtfuvrau38pao572p0k to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_128.txt as id=fvt8fhou295nlgbm2i9r to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_129.txt as id=fvtd57gsha3bhejv1im9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_130.txt as id=fvt90dbclb9369f3ruai to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_131.txt as id=fvte4qsin8o6pmh889js to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_132.txt as id=fvtao0ioskn2g9ujhj42 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_133.txt as id=fvttpnht74se19c4paek to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_134.txt as id=fvtuiifn51qgtto6v1pg to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_135.txt as id=fvtsv5chv695dq082l66 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_136.txt as id=fvt1oim0nftuu6ph1ia3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_137.txt as id=fvt6msupappc3bu0jras to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_138.txt as id=fvtulu5spkjkugdb7ct5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_139.txt as id=fvtd161efohe9taud81r to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_140.txt as id=fvtikal07ega50b47b6d to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_141.txt as id=fvtdrpa2oo2tqi7dod5e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_142.txt as id=fvt0sodtmj3srlc0t670 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_143.txt as id=fvt0ls96r3rl5597c2ts to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_144.txt as id=fvt7rnf2vldan3tiogcm to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_145.txt as id=fvts56g2559qpqugiphe to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_146.txt as id=fvt8thhnbrkd1pc51top to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_147.txt as id=fvtdtugibauvcfaeif5l to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_148.txt as id=fvtin8vjrfop0p21ul1r to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_149.txt as id=fvtc6b44it7i9ikir39o to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_150.txt as id=fvtgid3grql8u6ebg7lq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_151.txt as id=fvt5p210uviusu86l064 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_152.txt as id=fvt0u62vlrvmjkfe1466 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_153.txt as id=fvtlcldij7br4kiu1bua to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_154.txt as id=fvtch1r4g3rgnbcci10e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_155.txt as id=fvtl1rahqm93jgp36c4b to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_156.txt as id=fvtn1e1dm9sbmj1sln6i to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_157.txt as id=fvtjfea1rbphbhe3v5aa to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_158.txt as id=fvt60suj8tvv6oqqohnl to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_159.txt as id=fvta36e751nnkns2jonb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_160.txt as id=fvtbmt9tqtiiq51v2uf8 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_161.txt as id=fvt593hu5atccas32dgp to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_162.txt as id=fvtjnu00jvpgjn8g5a17 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_163.txt as id=fvt1186t59q5cq72mvie to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_164.txt as id=fvte4lhifbq2dggt67gu to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_165.txt as id=fvt6ijn28h4bbbd3fq2d to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_166.txt as id=fvt1980d2p1rcos63pkr to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_167.txt as id=fvt82ei5a9rcrh6kv0ko to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_168.txt as id=fvtqk1nfqnc7vblaigad to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_169.txt as id=fvt34ijg577g2kp5ssc8 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_170.txt as id=fvtnogq0jd8rus87tl9m to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_171.txt as id=fvttqt1v9snahdjo31f1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_172.txt as id=fvt9ct9hiadr9n0ecgpf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_173.txt as id=fvtep0hl6m1tsrqrd5er to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_174.txt as id=fvtfteqk0c9p72h3cv8e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_175.txt as id=fvtggj6a9ih0bth3hnh4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_176.txt as id=fvt1esbnuo11ctgcnbqk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_177.txt as id=fvt9qngufc6cur4th8pq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_178.txt as id=fvtng3vpb3bculie9qtv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_179.txt as id=fvthdbbkjoq919at99uv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_180.txt as id=fvtrliv32l1d5fc2icql to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_181.txt as id=fvt6lfgh7gkpc3je4knm to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_182.txt as id=fvtdm36979qrfo68r3ha to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_183.txt as id=fvt23hraj4uj3f3d1f5b to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_184.txt as id=fvtl8aeg2aprr1lja1h1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_185.txt as id=fvtkcib695vb7fr5vthi to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_186.txt as id=fvt5r20jrrt7olnbo6cq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_187.txt as id=fvtqbo27r6oo1nadovhd to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_188.txt as id=fvt636gedc92t2dgl60n to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_189.txt as id=fvtcbm994f7hhpqq04ck to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_190.txt as id=fvt5s2e89memap2k44nn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_191.txt as id=fvtumfgrrasc8lcqsfoq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_192.txt as id=fvtrqfr6mir8ggikhf17 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_193.txt as id=fvtmdrll5n03upm6gf9n to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_194.txt as id=fvt8vjp38bcuctp6f7v1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_195.txt as id=fvtglmnle1nksnteffqh to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_196.txt as id=fvtaoo59fjrd7019p6en to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_197.txt as id=fvtui6c97g9m0l9co1g3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_198.txt as id=fvtmarlb32n51jhd1i75 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_199.txt as id=fvtrm9gajri950009e85 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_200.txt as id=fvtnbjg2lkea8lheunk6 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_201.txt as id=fvtetbu8j65vign38bav to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_202.txt as id=fvtvpi7lc7ia9c4t6b6c to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_203.txt as id=fvt40mc2ks61gaa1h0gn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_204.txt as id=fvtdct9ggfdcr1h283od to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_205.txt as id=fvtp8cmfl1i82mj7q7uv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_206.txt as id=fvtglrjrtbnjanevsccg to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_207.txt as id=fvts3tn62ckmvh82292b to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_208.txt as id=fvt84219cq7n1trdp383 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_209.txt as id=fvtrkh1vtkh31ormfg70 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_210.txt as id=fvtlbj80q6soa13hs1u8 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_211.txt as id=fvtdu0h6vd0a2qjgt70g to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_212.txt as id=fvt3qg8q1udlcqc6gait to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_213.txt as id=fvtgaghh9enstr2r69sv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_214.txt as id=fvtdibpdumrcfn37509f to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_215.txt as id=fvtraoioos5dr9f0o7hn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_216.txt as id=fvtdmu6qvh6nlc3oka2a to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_217.txt as id=fvtlt4o43kadis21pknk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_218.txt as id=fvtc9vdqcq706i8j5cb7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_219.txt as id=fvtt8unspv7s519pfjt1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_220.txt as id=fvtfkls2se6v7bgasmih to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_221.txt as id=fvt1uc2f95m2qtb2pmnj to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_222.txt as id=fvtlaosc1kclcftb08r1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_223.txt as id=fvtok1mhmit981d12lvv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_224.txt as id=fvtudl9f7g9quhkvcqr0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_225.txt as id=fvtl0r41loclcetfg32n to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_226.txt as id=fvtl7iphodvufdon0cjt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_227.txt as id=fvtb9969sm4823td2est to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_228.txt as id=fvt2miccupsc23dtqndc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_229.txt as id=fvtiem05ru6hqs30kp8e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_230.txt as id=fvtk4fsnetcnb80lpvo4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_231.txt as id=fvtdtvj5j1ckj62sl7ih to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_232.txt as id=fvtttgeuofki98da5hk1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_233.txt as id=fvtntoh53j5ja5ijpmbn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_234.txt as id=fvte0sq2vmoli07qriu4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_235.txt as id=fvt5qcvgisgh5g2cno85 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_236.txt as id=fvt8v0n743acteihmqik to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_237.txt as id=fvtrobqj795cjvlg4tlt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_238.txt as id=fvtiknfgjs1tna504p3m to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_239.txt as id=fvt7s2vfqdf8kaambm4m to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_240.txt as id=fvtbvuj6lmj966l4ohat to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_241.txt as id=fvt56undm4bsdsu08gqi to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_242.txt as id=fvtlnbdufm4gte2f45bt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_243.txt as id=fvtjj8n3t90edmpl24fl to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_244.txt as id=fvtfbaijb8dmbrbbn9cg to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_245.txt as id=fvt1j23uligm3b06epb0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_246.txt as id=fvt0ubdmau2hs5789j26 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_247.txt as id=fvtspc88fabj3i6h06gv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_248.txt as id=fvtj0vnthflpibto2lrk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_249.txt as id=fvtlgq654p90e5b93hub to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_250.txt as id=fvtiupbqg8pmqcmml4qb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_251.txt as id=fvtbbuoplmbek6f5p85f to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_252.txt as id=fvt8qlh9j7nvu6pma8qt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_253.txt as id=fvtj86qk1tgdcf4b3ds6 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_254.txt as id=fvto8i203lmjj7ki1pft to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_255.txt as id=fvt1udv7frn1ct40o4ko to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_256.txt as id=fvtt09a0vefb2cpcjdah to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_257.txt as id=fvt9hfds2clubf8re3o3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_258.txt as id=fvtqm9jondp0bahk8gnr to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_259.txt as id=fvtear7qgq91qgir99pe to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_260.txt as id=fvtronruglgcv4kobimp to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_261.txt as id=fvtva45hpqgiqrseut73 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_262.txt as id=fvtnjlp52t09839u98h5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_263.txt as id=fvtlh09mqejrpq33jjan to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_264.txt as id=fvth4a2pfega5i1at7j2 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_265.txt as id=fvtpivdfm5g640geloog to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_266.txt as id=fvt16aut5latatmjsut1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_267.txt as id=fvtg9tlbkj2i68e6f83j to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_268.txt as id=fvt93ppqnuljnh50nht4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_269.txt as id=fvtbehgsqovl73r8vv0m to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_270.txt as id=fvtvoo4eesuo8068m1bd to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_271.txt as id=fvte2p9ndv42rsma6m18 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_272.txt as id=fvtbv5a4i4jvj1q0oj6b to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_273.txt as id=fvt61h0og39umotq6fco to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_274.txt as id=fvts42qomlh5ktrokihf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_275.txt as id=fvtfvt5qcqfvs8o1mdke to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_276.txt as id=fvt0hvq5damlfpo7vn7l to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_277.txt as id=fvtadub2tm5itmgkabp3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_278.txt as id=fvtilopp38ivgg8qptfi to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_279.txt as id=fvt4b8lv9d5mk6328up9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_280.txt as id=fvthvmr0j4ts6ebqkv5t to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_281.txt as id=fvtmqbvvl2ql5icua0ua to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_282.txt as id=fvt5p67gufbdd268j7qn to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_283.txt as id=fvtmfphs3l4ravbf2n0e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_284.txt as id=fvtit6fg4768tcp8eovb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_285.txt as id=fvtbbre0rtab6og0c6l9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_286.txt as id=fvtv3hhepjmbcr57kmnf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_287.txt as id=fvtudohuncouut0jaiqa to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_288.txt as id=fvt94pkf4akdv5862398 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_289.txt as id=fvtf81v46p6jtkh3rjj7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_290.txt as id=fvtmf7paejrjqh09405t to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_291.txt as id=fvtl9rd6cqiftmu9cbr3 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_292.txt as id=fvtaobaqjmb7p1k9ujo0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_293.txt as id=fvtkd4f7stnbddpqmve7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_294.txt as id=fvtrfk0icf3qglil8sv5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_295.txt as id=fvtot47kle1jvf32dcsc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_296.txt as id=fvtmoildl026fj9e289q to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_297.txt as id=fvtshe9h6rhilb1jdn3v to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_298.txt as id=fvtbq08ikrbuk7lr8qdd to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_299.txt as id=fvtfm3pt56vudq6euhm8 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_300.txt as id=fvtfmst2f3dj9nbc1abr to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_301.txt as id=fvth7u9qenjahhgalnqa to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_302.txt as id=fvtvrmu7srh706250edu to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_303.txt as id=fvtej4fn8pppauvdnb5p to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_304.txt as id=fvtllms8rggh5dla3kv0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_305.txt as id=fvtjb40lhr8keudoh5t1 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_306.txt as id=fvtdps4b67gib07nk1i5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_307.txt as id=fvtd3feitcr7k6kamafb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_308.txt as id=fvts5u9n6mm22ejhe0ri to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_309.txt as id=fvtpl5lqmbgnjvesk79k to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_310.txt as id=fvt007p7222nnrqhr1e5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_311.txt as id=fvtcpojdl586bohni0rj to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_312.txt as id=fvt2s6m6ngu8381o9641 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_313.txt as id=fvtvmsjohdkui6sllngv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_314.txt as id=fvtio562ck1an84s1b04 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_315.txt as id=fvto3s1gljl7vp8dvcgv to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_316.txt as id=fvtk9f836ggd77s665s2 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_317.txt as id=fvtome8gropfq31uuvmk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_318.txt as id=fvt6ajso3vfgmqm6cfh9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_319.txt as id=fvtcgg00687u3o7scss9 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_320.txt as id=fvtjn6fo4aqbc7fc976d to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_321.txt as id=fvte1guv3prta3k4qhah to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_322.txt as id=fvt7q1h71afgh2d6pc4u to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_323.txt as id=fvtqqt0e3k678ga0s64d to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_324.txt as id=fvt6pvelnf1h8h1nv21n to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_325.txt as id=fvtcanh8v7a1e2qjck01 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_326.txt as id=fvt7bvmcoqkoer1394d4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_327.txt as id=fvtimau6stpmv3ae0443 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_328.txt as id=fvth4538lb7ilhp2i6ae to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_329.txt as id=fvtvngu0ff5bilu172um to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_330.txt as id=fvts1e8mtea1ptu0er8j to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_331.txt as id=fvt833kdk38bfkn8agdq to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_332.txt as id=fvta3cihdnajah3euuu7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_333.txt as id=fvtc8e3nmu5qfkfjf61e to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_334.txt as id=fvtnjngl7kdrblk0ihs7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_335.txt as id=fvtkq2l5j9gp8irt60ft to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_336.txt as id=fvtcjhfj5eenfiunllvf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_337.txt as id=fvt502e8f5vee9rd1vhu to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_338.txt as id=fvtuq6gg3nq2ljpfjsja to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_339.txt as id=fvtfa2qhk9jb6v45poqh to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_340.txt as id=fvti5q200iouf4geee66 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_341.txt as id=fvtf8nqgpd0nd7rejqca to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_342.txt as id=fvt2mjfapsjcs7j6qrcj to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_343.txt as id=fvthiovfmgj89k26j7q0 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_344.txt as id=fvtl1u4ld187kn9a3025 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_345.txt as id=fvtk9jtq773v31i3eqc5 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_346.txt as id=fvtmtrigt8ua8fmjo4v7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_347.txt as id=fvt7g36nu36o9mtqn58p to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_348.txt as id=fvtstad7k15lsc8rsv2l to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_349.txt as id=fvtgcn3ptcs8vbue40o2 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_350.txt as id=fvtli8vakuuu8f77b8i7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_351.txt as id=fvt1mtush38scdierh6t to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_352.txt as id=fvtpb1jjddei4kdlahlb to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_353.txt as id=fvttia4mvbpugsqsd08l to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_354.txt as id=fvtd70lf6ga3lg84d500 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_355.txt as id=fvt21gse8de1i1m35qjt to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_356.txt as id=fvt38t2o9ticjh0094u4 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_357.txt as id=fvtt57jg7hpfciv2349s to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_358.txt as id=fvtr334jrk2d5q5o5vlf to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_359.txt as id=fvt6tf5l176la9ogdcih to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_360.txt as id=fvtgm3509ug3tt6guhec to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_361.txt as id=fvtjutotbsq9g5m4k2ch to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_362.txt as id=fvtumj2k8orm6kj6l2gu to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_363.txt as id=fvtn7tlj8nr6lrj0ostc to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_364.txt as id=fvt2orp82artai7nti96 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_365.txt as id=fvtthuust4hghr5q38ka to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_366.txt as id=fvtt6842hk3du2n1j5jr to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_367.txt as id=fvtcckuq9po829om1grk to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_368.txt as id=fvtr3gqsldju4d319gm7 to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_369.txt as id=fvtqjcsi5r6ms6c1fvri to store=fvtovs52bc72rmqrdeg1
#  + Uploading rag_consultant_370.txt as id=fvt2ha43m652hc8e6tg4 to store=fvtovs52bc72rmqrdeg1

# %%
printx(consultant("Что ты умеешь?"))
# Out:
# Я – консультант на складе поставщика продуктов для сегмента HoReCa. Я могу давать советы по продуктам и отвечать на вопросы об ассортименте, используя информацию из каталога. Если продукта нет в каталоге, я сообщу об этом. Для поиска информации я могу использовать функцию поиска по каталогу.

# %%
printx(consultant("Посоветуй продукты из каталога, которые можно использовать для приготовления блюда 'Борщ'"))
# Out:
# Для приготовления борща из нашего каталога вам могут понадобиться следующие продукты:
#
# *   **Заправка для Борща Dinner Service** (артикул 115873)
# *   **Заправка для Борща Bravolli Professional** (артикул 116477)
# *   **Набор для борща зам. Мираторг** (артикул 116446)
# *   **Свекла**, к сожалению, отсутствует в каталоге.
# *   **Капуста**, к сожалению, отсутствует в каталоге.
# *   **Картофель**, к сожалению, отсутствует в каталоге.
# *   **Мясо** (например, говядина или свинина), к сожалению, отсутствует в каталоге.
# *   **Томатная паста** (артикул 111948)
# *   **Перец черный горошек** (артикул 27117)
# *   **Масло подсолнечное** (артикул 112401)
